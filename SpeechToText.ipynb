# %% [markdown]
# <a href="https://colab.research.google.com/github/Umeshyadav5128/SpeechToText/blob/main/SpeechToText.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# speech to text convert using whisper model
# !pip install openai-whisper
# !pip install -y ffmpeg

import whisper
from google.colab import files

model = whisper.load_model("base")

uploaded = files.upload()
audio = list(uploaded.keys())[0]

result = model.transcribe(audio, fp16=False)

print(result["text"])
# Out:
# ...
#
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: -y
#      <input type="file" id="files-5ff5aae7-1335-4795-9615-9275ccec8587" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ff5aae7-1335-4795-9615-9275ccec8587">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# ...
